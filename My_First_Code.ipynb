# %% [markdown]
# <a href="https://colab.research.google.com/github/gracecodes15-stack/python-first-project/blob/main/My_First_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("What is your name:")
print("Welcome",name)
# Out:
# What is your name:gace
# Welcome gace
